# %%
load tap CEN_NDC.txt
# Out:
# Tap: elegant_lovelace

# %%
graph tap
# Out:
# Take a look at the produced graph.

# %%
graph worlds
# Out:
# 1 worlds have been produced.

# %%
load tap CEN_TZ.txt
# Out:
# Tap: eloquent_poincare

# %%
graph tap
# Out:
# Take a look at the produced graph.

# %%
graph worlds
# Out:
# 1 worlds have been produced.

# %%
set config defaultRegions=mncb
# Out:
# Configuration updated: defaultRegions = mncb

# %%
graph worlds
# Out:
# 1 worlds have been produced.
